# %%
#Exp no:

# %%
#Aim:To Perform Basics of Data Frame

# %%
#Name:sanika vijay kale
#Roll no:23
#Sec:c
#Subject:ET 2

# %% [markdown]
# # Creating series

# %%
# Program for creating Series using series() method of Pandas Library

# %%
#Import Pandas library
import pandas as pd

# %%
#Creating Student Name List
Name=["Sanika","Sandesha","Apurva","priya","Shruti"]
Name
# Out:
# ['Sanika', 'Sandesha', 'Apurva', 'priya', 'Shruti']

# %%
#Creating a Series 
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1      Sanika
# 2    Sandesha
# 3      Apurva
# 4       priya
# 5      Shruti
# dtype: object

# %% [markdown]
# # Creating Data Frame

# %%
#Import Pandas library
import pandas as pd

# %%
#Creating Data Frame
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
columns= ["BIA","DBMS","DSS","CAO"])

# %%
df
# Out:
#    BIA  DBMS  DSS  CAO
# 0   10    12   14   16
# 1   11    18   15   21
# 2   12    13   14   15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record(Row)to the data frame

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns= ["BIA","DBMS","DSS","CAO"])

# %%
df3=df.append(df2,ignore_index=True)
# Out:
# C:\Users\anike\AppData\Local\Temp/ipykernel_14652/2783945210.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3=df.append(df2,ignore_index=True)

# %%
df3
# Out:
#     BIA  DBMS  DSS  CAO   CD  DM
# 0  10.0    12   14   16  NaN  12
# 1  11.0    18   15   21  NaN  15
# 2  12.0    13   14   15  NaN  16
# 3   NaN     6    7    8  5.0  14

# %% [markdown]
# # Adding Attribute(coloums)name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#     BIA  DBMS  DSS  CAO   CD  DM
# 0  10.0    12   14   16  NaN  12
# 1  11.0    18   15   21  NaN  15
# 2  12.0    13   14   15  NaN  16
# 3   NaN     6    7    8  5.0  14

# %% [markdown]
# # Deleting Record Frome df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#     BIA  DBMS  DSS  CAO   CD  DM
# 0  10.0    12   14   16  NaN  12
# 2  12.0    13   14   15  NaN  16
# 3   NaN     6    7    8  5.0  14

# %% [markdown]
# # Deleting Attribute (coloums)from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#     BIA  DBMS  DSS  CAO   CD
# 0  10.0    12   14   16  NaN
# 1  11.0    18   15   21  NaN
# 2  12.0    13   14   15  NaN
# 3   NaN     6    7    8  5.0

# %%
#Finding mean of DSS 

print("Mean of DSS:", df5["DSS"].mean())
# Out:
# Mean of DSS: 12.5

# %%
#Finding median of DSS

print("Median of DSS:", df5["DSS"].median())
# Out:
# Median of DSS: 14.0

# %%
#Finding mode of DSS

print("Mode of DSS:", df5["DSS"].mode())
# Out:
# Mode of DSS: 0    14
# Name: DSS, dtype: int64

# %%
#Finding max number of DSS

print("Max of DSS:", df5["DSS"].max())
# Out:
# Max of DSS: 15

# %%
#Finding Min number of DSS

print("Max of DSS:", df5["DSS"].min())
# Out:
# Max of DSS: 7
